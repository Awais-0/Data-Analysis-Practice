# %%
import requests
from bs4 import BeautifulSoup
import csv

response = requests.get('https://www.passiton.com/inspirational-quotes')

soup = BeautifulSoup(response.text)

# %%
quotes = []

for div in soup.find_all('div', class_ = 'text-center mb-8'):
    quotes.append(div.find('p', class_ = 'text-white').text)

print(quotes)
# Out:
# ['“Every great story happened when someone decided not to give up.”', '“Only those who will risk going too far can possibly find out how far one can go.”', '“What is grit? Grit is refusing to give up. It’s persistence. It’s making your own luck.”', "“Once you choose hope, anything's possible.”", '“Someday all you’ll have to light the way will be a single ray of hope, and that will be enough.”', '“It is often in the darkest skies that we see the brightest stars.”', '“Let your hopes, not your hurts, shape your future.”', '“Hope sees the invisible, feels the intangible, and achieves the impossible.”', '“The essence of life is not in the great victories and grand failures, but in the simple joys.”', '“The joy of giving is the greatest joy of life.”', '“Happiness—not in another place, but this place... not for another hour, but for this hour.”', '“Joy is the kind of happiness that doesn’t depend on what happens.”', '“If you carry joy in your heart, you can heal any moment.”', "“Don't worry when you are not recognized, but strive to be worthy of recognition. ”", "“I have not failed. I've just found 10,000 ways that won't work.”", '“When you start to develop your powers of empathy and imagination, the whole world opens up to you.”', '“The only person you are destined to become is the person you decide to be.”', '“When we strive to become better than we are, everything around us becomes better, too.”', '“Practice like you’ve never won. Play like you’ve never lost.”', '“Practice is the best of all instructors.”', '“Talent is a pursued interest. Anything that you’re willing to practice, you can do.”', '“The difference between ordinary and extraordinary is practice.”', '“Practice creates confidence. Confidence empowers you.”', '“No one has ever become poor by giving.”', '“The more generous we are, the more joyous we become.”', "“Sometimes when we are generous in small, barely detectable ways it can change someone else's life forever.”", '“The greatest gift you ever give is your honest self.”', '“Good actions give strength to ourselves and inspire good actions in others.”', '“The more grateful I am, the more beauty I see.”', '“As we express our gratitude, we must never forget that the highest appreciation is not to utter words, but to live by them.”', '“Showing gratitude is one of the simplest yet most powerful things humans can do for each other.”', '“Start each day with a positive thought and a grateful heart.”', '“Gratitude unlocks the fullness of life. It turns what we have into enough, and more.”']

# %%
print(len(quotes))
# for quote in quotes:
#     with open('quotes.txt', 'a', encoding='utf-8') as file:
#         writer = file.write(quote + '\n')
# Out:
# 33
